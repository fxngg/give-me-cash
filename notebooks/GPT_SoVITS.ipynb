# %% [markdown]
# <a href="https://colab.research.google.com/github/fxngg/give-me-cash/blob/main/notebooks/GPT_SoVITS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/KevinWang676/gpt-sovits.git
# Out:
# fatal: destination path 'gpt-sovits' already exists and is not an empty directory.

# %%
# !git clone https://huggingface.co/spaces/kevinwang676/GPT-SoVITS.git
# Out:
# fatal: destination path 'GPT-SoVITS' already exists and is not an empty directory.

# %%
pip install torch numpy scipy tensorboard librosa==0.9.2 numba==0.56.4 pytorch-lightning gradio==3.38.0 ffmpeg-python onnxruntime tqdm cn2an pypinyin pyopenjtalk g2p_en chardet
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.15.2)
# Requirement already satisfied: librosa==0.9.2 in /usr/local/lib/python3.10/dist-packages (0.9.2)
# Requirement already satisfied: numba==0.56.4 in /usr/local/lib/python3.10/dist-packages (0.56.4)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: gradio==3.38.0 in /usr/local/lib/python3.10/dist-packages (3.38.0)
# Requirement already satisfied: ffmpeg-python in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.10/dist-packages (1.17.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.2)
# Requirement already satisfied: cn2an in /usr/local/lib/python3.10/dist-packages (0.5.22)
# Requirement already satisfied: pypinyin in /usr/local/lib/python3.10/dist-packages (0.51.0)
# Requirement already satisfied: pyopenjtalk in /usr/local/lib/python3.10/dist-packages (0.3.3)
# Requirement already satisfied: g2p_en in /usr/local/lib/python3.10/dist-packages (2.1.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2) (1.4.0)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2) (4.4.2)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2) (0.4.3)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2) (1.8.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from librosa==0.9.2) (24.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba==0.56.4) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba==0.56.4) (67.7.2)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (23.2.1)
# Requirement already satisfied: aiohttp~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (3.9.3)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (4.2.2)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (0.110.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (0.3.2)
# Requirement already satisfied: gradio-client>=0.2.10 in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (0.15.1)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (0.20.3)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (3.1.3)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (2.2.0)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (3.7.1)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (0.3.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (3.10.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (2.0.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (9.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (2.6.4)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (0.25.1)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (6.0.1)
# Requirement already satisfied: requests~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (2.31.0)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (2.10.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (4.11.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (0.29.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.38.0) (11.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.4.127)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.62.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.0.2)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (1.3.2)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (0.11.2)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from ffmpeg-python) (0.18.3)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime) (24.3.25)
# Requirement already satisfied: proces>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from cn2an) (0.1.7)
# Requirement already satisfied: nltk>=3.2.4 in /usr/local/lib/python3.10/dist-packages (from g2p_en) (3.8.1)
# Requirement already satisfied: inflect>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from g2p_en) (7.0.0)
# Requirement already satisfied: distance>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from g2p_en) (0.1.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp~=3.0->gradio==3.38.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp~=3.0->gradio==3.38.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp~=3.0->gradio==3.38.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp~=3.0->gradio==3.38.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp~=3.0->gradio==3.38.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp~=3.0->gradio==3.38.0) (4.0.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.38.0) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.38.0) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==3.38.0) (0.12.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==3.38.0) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==3.38.0) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==3.38.0) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==3.38.0) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==3.38.0) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->gradio==3.38.0) (0.14.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.38.0) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.38.0) (2.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.38.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.38.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.38.0) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.38.0) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.38.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==3.38.0) (2.8.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.4->g2p_en) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.2.4->g2p_en) (2023.12.25)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==3.38.0) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==3.38.0) (2024.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa==0.9.2) (4.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4->gradio==3.38.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4->gradio==3.38.0) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio==3.38.0) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests~=2.0->gradio==3.38.0) (2.0.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.1->librosa==0.9.2) (3.4.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.10.2->librosa==0.9.2) (1.16.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio==3.38.0) (0.37.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.9.2) (2.22)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.38.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.38.0) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.38.0) (0.18.0)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.10/dist-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio==3.38.0) (1.0.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard) (3.2.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->gradio==3.38.0) (1.2.0)

# %%
pip install modelscope==1.11.0 torchaudio sentencepiece funasr==0.8.8
# Out:
# Collecting modelscope==1.11.0
#   Using cached modelscope-1.11.0-py3-none-any.whl (5.5 MB)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (0.1.99)
# Collecting funasr==0.8.8
#   Using cached funasr-0.8.8-py3-none-any.whl (750 kB)
# Collecting addict (from modelscope==1.11.0)
#   Using cached addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from modelscope==1.11.0) (23.2.0)
# Collecting datasets>=2.14.5 (from modelscope==1.11.0)
#   Using cached datasets-2.18.0-py3-none-any.whl (510 kB)
# Collecting einops (from modelscope==1.11.0)
#   Using cached einops-0.7.0-py3-none-any.whl (44 kB)
# Requirement already satisfied: filelock>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from modelscope==1.11.0) (3.13.4)
# Requirement already satisfied: gast>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from modelscope==1.11.0) (0.5.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from modelscope==1.11.0) (1.23.5)
# Collecting oss2 (from modelscope==1.11.0)
#   Using cached oss2-2.18.4.tar.gz (278 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from modelscope==1.11.0) (2.0.3)
# Requirement already satisfied: Pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from modelscope==1.11.0) (9.4.0)
# Requirement already satisfied: pyarrow!=9.0.0,>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from modelscope==1.11.0) (14.0.2)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.10/dist-packages (from modelscope==1.11.0) (2.8.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from modelscope==1.11.0) (6.0.1)
# Requirement already satisfied: requests>=2.25 in /usr/local/lib/python3.10/dist-packages (from modelscope==1.11.0) (2.31.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from modelscope==1.11.0) (1.11.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from modelscope==1.11.0) (67.7.2)
# Collecting simplejson>=3.3.0 (from modelscope==1.11.0)
#   Using cached simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
# Requirement already satisfied: sortedcontainers>=1.5.9 in /usr/local/lib/python3.10/dist-packages (from modelscope==1.11.0) (2.4.0)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from modelscope==1.11.0) (4.66.2)
# Requirement already satisfied: urllib3>=1.26 in /usr/local/lib/python3.10/dist-packages (from modelscope==1.11.0) (2.0.7)
# Collecting yapf (from modelscope==1.11.0)
#   Using cached yapf-0.40.2-py3-none-any.whl (254 kB)
# Requirement already satisfied: humanfriendly in /usr/local/lib/python3.10/dist-packages (from funasr==0.8.8) (10.0)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (from funasr==0.8.8) (0.9.2)
# Collecting jamo (from funasr==0.8.8)
#   Downloading jamo-0.4.1-py3-none-any.whl (9.5 kB)
# Collecting kaldiio>=2.17.0 (from funasr==0.8.8)
#   Downloading kaldiio-2.18.0-py3-none-any.whl (28 kB)
# Collecting torch-complex (from funasr==0.8.8)
#   Downloading torch_complex-0.4.3-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: jieba in /usr/local/lib/python3.10/dist-packages (from funasr==0.8.8) (0.42.1)
# Collecting pytorch-wpe (from funasr==0.8.8)
#   Downloading pytorch_wpe-0.0.1-py3-none-any.whl (8.1 kB)
# Requirement already satisfied: editdistance>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from funasr==0.8.8) (0.6.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from funasr==0.8.8) (2.15.2)
# Collecting hdbscan (from funasr==0.8.8)
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 18.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting umap (from funasr==0.8.8)
#   Downloading umap-0.1.1.tar.gz (3.2 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jaconv (from funasr==0.8.8)
#   Downloading jaconv-0.3.4.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch==2.2.1 in /usr/local/lib/python3.10/dist-packages (from torchaudio) (2.2.1+cu121)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.2.1->torchaudio) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.1->torchaudio) (12.4.127)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.5->modelscope==1.11.0) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.14.5->modelscope==1.11.0)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 18.8 MB/s eta 0:00:00
# Collecting xxhash (from datasets>=2.14.5->modelscope==1.11.0)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 28.6 MB/s eta 0:00:00
# Collecting multiprocess (from datasets>=2.14.5->modelscope==1.11.0)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.5->modelscope==1.11.0) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.5->modelscope==1.11.0) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets>=2.14.5->modelscope==1.11.0) (24.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.1->modelscope==1.11.0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25->modelscope==1.11.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25->modelscope==1.11.0) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25->modelscope==1.11.0) (2024.2.2)
# Collecting cython<3,>=0.27 (from hdbscan->funasr==0.8.8)
#   Using cached Cython-0.29.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.10/dist-packages (from hdbscan->funasr==0.8.8) (1.2.2)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan->funasr==0.8.8) (1.4.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa->funasr==0.8.8) (3.0.1)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.10/dist-packages (from librosa->funasr==0.8.8) (4.4.2)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from librosa->funasr==0.8.8) (0.4.3)
# Requirement already satisfied: numba>=0.45.1 in /usr/local/lib/python3.10/dist-packages (from librosa->funasr==0.8.8) (0.56.4)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from librosa->funasr==0.8.8) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa->funasr==0.8.8) (1.8.1)
# Collecting crcmod>=1.7 (from oss2->modelscope==1.11.0)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 14.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pycryptodome>=3.4.7 (from oss2->modelscope==1.11.0)
#   Downloading pycryptodome-3.20.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 37.7 MB/s eta 0:00:00
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2->modelscope==1.11.0)
#   Downloading aliyun_python_sdk_kms-2.16.2-py2.py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 14.2 MB/s eta 0:00:00
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2->modelscope==1.11.0)
#   Downloading aliyun-python-sdk-core-2.15.0.tar.gz (443 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.1/443.1 kB 40.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->modelscope==1.11.0) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->modelscope==1.11.0) (2024.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->funasr==0.8.8) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->funasr==0.8.8) (1.62.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->funasr==0.8.8) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->funasr==0.8.8) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->funasr==0.8.8) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->funasr==0.8.8) (3.20.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->funasr==0.8.8) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->funasr==0.8.8) (3.0.2)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /usr/local/lib/python3.10/dist-packages (from yapf->modelscope==1.11.0) (7.1.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->modelscope==1.11.0) (4.2.0)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->modelscope==1.11.0) (2.0.1)
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2->modelscope==1.11.0)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: cryptography>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2->modelscope==1.11.0) (42.0.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.5->modelscope==1.11.0) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.5->modelscope==1.11.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.5->modelscope==1.11.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.5->modelscope==1.11.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.14.5->modelscope==1.11.0) (4.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->funasr==0.8.8) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->funasr==0.8.8) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->funasr==0.8.8) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard->funasr==0.8.8) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->yapf->modelscope==1.11.0) (3.18.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.45.1->librosa->funasr==0.8.8) (0.39.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20->hdbscan->funasr==0.8.8) (3.4.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.10.2->librosa->funasr==0.8.8) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->funasr==0.8.8) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.2.1->torchaudio) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa->funasr==0.8.8) (2.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->funasr==0.8.8) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard->funasr==0.8.8) (3.2.2)
# Building wheels for collected packages: hdbscan, jaconv, oss2, umap, aliyun-python-sdk-core, crcmod
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039286 sha256=9b935989d6a186af7470c2b6b0bea2c336a1d7be94c6861c28457aa2813631cc
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
#   Building wheel for jaconv (setup.py) ... done
#   Created wheel for jaconv: filename=jaconv-0.3.4-py3-none-any.whl size=16416 sha256=71f0ae0a35969e5291c966f679b104dcae663012cada3eb393fc4d1879ad8863
#   Stored in directory: /root/.cache/pip/wheels/46/8f/2e/a730bf1fca05b33e532d5d91dabdf406c9b718ec85b01b1b54
#   Building wheel for oss2 (setup.py) ... done
#   Created wheel for oss2: filename=oss2-2.18.4-py3-none-any.whl size=115939 sha256=970c998a3ae5883646dc366827c1da631ecaebe1361ea3c8ff1fc88170d16673
#   Stored in directory: /root/.cache/pip/wheels/9e/34/68/f21dc0320c699eb02ab90f2f7965d6f60ee793f03ef5e23212
#   Building wheel for umap (setup.py) ... done
#   Created wheel for umap: filename=umap-0.1.1-py3-none-any.whl size=3543 sha256=9464bbe13f4e7e6bd918cb102ce508b19f546b2b8d83f90f31ccf98ae39c152a
#   Stored in directory: /root/.cache/pip/wheels/15/f1/28/53dcf7a309118ed35d810a5f9cb995217800f3f269ab5771cb
#   Building wheel for aliyun-python-sdk-core (setup.py) ... done
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.15.0-py3-none-any.whl size=535311 sha256=325961f7a40026e91eb48febe4ed3461299cfd3dc78e291af6e513bae4de25cb
#   Stored in directory: /root/.cache/pip/wheels/b7/28/7c/a888bb3c60c865d014c7ef5017c83fdbc1cb0f601b79c7794a
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=31406 sha256=ff7437ec94d2dc9663ab0ede16407c0d96bee86e4e2770d599c967b2cce38313
#   Stored in directory: /root/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
# Successfully built hdbscan jaconv oss2 umap aliyun-python-sdk-core crcmod
# Installing collected packages: umap, jamo, jaconv, crcmod, addict, xxhash, torch-complex, simplejson, pytorch-wpe, pycryptodome, kaldiio, jmespath, einops, dill, cython, yapf, multiprocess, hdbscan, aliyun-python-sdk-core, datasets, aliyun-python-sdk-kms, oss2, modelscope, funasr
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.10
#     Uninstalling Cython-3.0.10:
#       Successfully uninstalled Cython-3.0.10
# Successfully installed addict-2.4.0 aliyun-python-sdk-core-2.15.0 aliyun-python-sdk-kms-2.16.2 crcmod-1.7 cython-0.29.37 datasets-2.18.0 dill-0.3.8 einops-0.7.0 funasr-0.8.8 hdbscan-0.8.33 jaconv-0.3.4 jamo-0.4.1 jmespath-0.10.0 kaldiio-2.18.0 modelscope-1.11.0 multiprocess-0.70.16 oss2-2.18.4 pycryptodome-3.20.0 pytorch-wpe-0.0.1 simplejson-3.19.2 torch-complex-0.4.3 umap-0.1.1 xxhash-3.4.1 yapf-0.40.2

# %%
# !sudo apt install ffmpeg
# !sudo apt install libsox-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libsox-dev is already the newest version (14.4.2+git20190427-2+deb11u2ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
# !mv /content/GPT-SoVITS/GPT-SoVITS/tools/damo_asr/models /content/gpt-sovits/tools/damo_asr

# %%
# !mv /content/GPT-SoVITS/GPT-SoVITS/GPT_SoVITS/pretrained_models /content/gpt-sovits/GPT_SoVITS

# %%
cd gpt-sovits
# Out:
# /content/gpt-sovits

# %%
import nltk
nltk.download("all")
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to /root/nltk_data...
# [nltk_data]    | Downloading package conll2000 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to /root/nltk_data...
# [nltk_data]    | Downloading package crubadan to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package floresta to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package ieer to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to /root/nltk_data...
# [nltk_data]    | Downloading package kimmo to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to /root/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to /root/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to /root/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package mte_teip5 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to /root/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to /root/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/nps_chat.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package paradigms to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to /root/nltk_data...
# [nltk_data]    | Downloading package pros_cons to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package qc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to /root/nltk_data...
# [nltk_data]    | Downloading package rslp to /root/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to /root/nltk_data...
# [nltk_data]    | Downloading package senseval to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to /root/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package verbnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to /root/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package ycoe to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
# !python webui.py
# Out:
# Running on local URL:  http://0.0.0.0:9874
# Running on public URL: https://4e36204e0144b07c21.gradio.live
# "/usr/bin/python3" tools/uvr5/webui.py "cuda" True 9873
# /usr/local/lib/python3.10/dist-packages/gradio_client/documentation.py:103: UserWarning: Could not get documentation group for <class 'gradio.mix.Parallel'>: No known documentation group for module 'gradio.mix'
#   warnings.warn(f"Could not get documentation group for {cls}: {exc}")
# /usr/local/lib/python3.10/dist-packages/gradio_client/documentation.py:103: UserWarning: Could not get documentation group for <class 'gradio.mix.Series'>: No known documentation group for module 'gradio.mix'
#   warnings.warn(f"Could not get documentation group for {cls}: {exc}")
# "/usr/bin/python3" tools/slice_audio.py "/content/ai合成音.MP3" "output/slicer_opt" -34 4000 300 10 500 0.9 0.25 0 1
# 执行完毕，请检查输出文件
# "/usr/bin/python3" tools/damo_asr/cmd-asr.py "output/slicer_opt"
# 2024-04-15 08:47:56,689 - modelscope - INFO - PyTorch version 2.2.1+cu121 Found.
# 2024-04-15 08:47:56,692 - modelscope - INFO - TensorFlow version 2.15.0 Found.
# 2024-04-15 08:47:56,692 - modelscope - INFO - Loading ast index from /root/.cache/modelscope/ast_indexer
# 2024-04-15 08:47:56,692 - modelscope - INFO - No valid ast index found from /root/.cache/modelscope/ast_indexer, generating ast index from prebuilt!
# 2024-04-15 08:47:56,784 - modelscope - INFO - Loading done! Current index file version is 1.11.0, with md5 d98e6ee59e4d04140e9dd26dd1a4ce31 and a total number of 953 components indexed
# 2024-04-15 08:48:01.442925: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-15 08:48:01.442979: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-15 08:48:01.542852: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-15 08:48:03.640712: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-15 08:48:04,875 - modelscope - INFO - initiate model from tools/damo_asr/models/speech_paraformer-large_asr_nat-zh-cn-16k-common-vocab8404-pytorch
# 2024-04-15 08:48:04,875 - modelscope - INFO - initiate model from location tools/damo_asr/models/speech_paraformer-large_asr_nat-zh-cn-16k-common-vocab8404-pytorch.
# 2024-04-15 08:48:04,876 - modelscope - INFO - initialize model from tools/damo_asr/models/speech_paraformer-large_asr_nat-zh-cn-16k-common-vocab8404-pytorch
# 2024-04-15 08:48:04,878 - modelscope - WARNING - No preprocessor field found in cfg.
# 2024-04-15 08:48:04,878 - modelscope - WARNING - No val key and type key found in preprocessor domain of configuration.json file.
# 2024-04-15 08:48:04,878 - modelscope - WARNING - Cannot find available config to build preprocessor at mode inference, current config: {'model_dir': 'tools/damo_asr/models/speech_paraformer-large_asr_nat-zh-cn-16k-common-vocab8404-pytorch'}. trying to build by task and model information.
# 2024-04-15 08:48:04,878 - modelscope - WARNING - No preprocessor key ('generic-asr', 'auto-speech-recognition') found in PREPROCESSOR_MAP, skip building preprocessor.
# 2024-04-15 08:48:06,817 - modelscope - WARNING - Model revision not specified, use revision: v2.0.0
# Downloading: 100% 10.9k/10.9k [00:00<00:00, 36.3MB/s]
# Downloading: 100% 173k/173k [00:00<00:00, 3.97MB/s]
# Downloading: 100% 2.50k/2.50k [00:00<00:00, 12.6MB/s]
# Downloading: 100% 381/381 [00:00<00:00, 1.52MB/s]
# Downloading: 100% 226M/226M [00:01<00:00, 126MB/s]
# Downloading: 100% 53.1k/53.1k [00:00<00:00, 1.70MB/s]
# Downloading: 100% 840M/840M [00:05<00:00, 157MB/s]
# Downloading: 100% 32.2k/32.2k [00:00<00:00, 2.25MB/s]
# Downloading: 100% 7.90M/7.90M [00:00<00:00, 47.0MB/s]
# Downloading: 100% 48.7k/48.7k [00:00<00:00, 1.59MB/s]
# Downloading: 100% 34.0k/34.0k [00:00<00:00, 2.10MB/s]
# 2024-04-15 08:48:27,521 - modelscope - INFO - loading vad model from tools/damo_asr/models/speech_fsmn_vad_zh-cn-16k-common-pytorch ...
# 2024-04-15 08:48:27,525 - modelscope - INFO - loading punctuation model from tools/damo_asr/models/punc_ct-transformer_zh-cn-common-vocab272727-pytorch ...
# Please install rotary_embedding_torch by:
#  pip install -U rotary_embedding_torch
# 2024-04-15 08:48:56,424 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.3209366798400879
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  2.1435208320617676
# 100% 1/1 [00:02<00:00,  2.14s/it]
# total time cost asr:  2.144672155380249
# time cost punc:  0.047891855239868164
# 2024-04-15 08:48:59,406 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:48:59,425 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.09381699562072754
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.1283273696899414
# 100% 1/1 [00:00<00:00,  7.74it/s]
# total time cost asr:  0.12954449653625488
# time cost punc:  0.008219480514526367
# 2024-04-15 08:49:00,148 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:00,166 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.08064675331115723
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.12148880958557129
# 100% 2/2 [00:00<00:00, 16.33it/s]
# total time cost asr:  0.12290620803833008
# time cost punc:  0.008777379989624023
# 2024-04-15 08:49:00,887 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:00,908 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.06387734413146973
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.133392333984375
# 100% 1/1 [00:00<00:00,  7.45it/s]
# total time cost asr:  0.13464617729187012
# time cost punc:  0.008642435073852539
# 2024-04-15 08:49:01,630 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:01,648 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.0923161506652832
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.08475852012634277
# 100% 2/2 [00:00<00:00, 23.43it/s]
# total time cost asr:  0.08575797080993652
# time cost punc:  0.0057408809661865234
# 2024-04-15 08:49:02,330 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:02,341 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.06168866157531738
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.09929513931274414
# 100% 1/1 [00:00<00:00, 10.00it/s]
# total time cost asr:  0.10042762756347656
# time cost punc:  0.007134199142456055
# 2024-04-15 08:49:02,809 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:02,820 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.0566866397857666
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.10429048538208008
# 100% 2/2 [00:00<00:00, 19.03it/s]
# total time cost asr:  0.10538864135742188
# time cost punc:  0.006285190582275391
# 2024-04-15 08:49:03,300 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:03,312 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.05614662170410156
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.09367680549621582
# 100% 2/2 [00:00<00:00, 21.19it/s]
# total time cost asr:  0.0947871208190918
# time cost punc:  0.007481575012207031
# 2024-04-15 08:49:03,781 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:03,793 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.06905579566955566
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.09742903709411621
# 100% 1/1 [00:00<00:00, 10.19it/s]
# total time cost asr:  0.0984811782836914
# time cost punc:  0.017401456832885742
# 2024-04-15 08:49:04,277 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:04,292 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.043486595153808594
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.09110426902770996
# 100% 2/2 [00:00<00:00, 21.82it/s]
# total time cost asr:  0.09201931953430176
# time cost punc:  0.005694389343261719
# 2024-04-15 08:49:04,739 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:04,749 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.04490828514099121
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.08376550674438477
# 100% 2/2 [00:00<00:00, 23.70it/s]
# total time cost asr:  0.0847470760345459
# time cost punc:  0.0068318843841552734
# 2024-04-15 08:49:05,187 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:05,198 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.04562878608703613
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.08634495735168457
# 100% 2/2 [00:00<00:00, 23.01it/s]
# total time cost asr:  0.08731675148010254
# time cost punc:  0.005783796310424805
# 2024-04-15 08:49:05,648 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:05,659 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.039301156997680664
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.08038520812988281
# 100% 2/2 [00:00<00:00, 24.71it/s]
# total time cost asr:  0.08130669593811035
# time cost punc:  0.005203723907470703
# 2024-04-15 08:49:06,086 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:06,098 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.057497501373291016
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.08954405784606934
# 100% 1/1 [00:00<00:00, 11.10it/s]
# total time cost asr:  0.09054136276245117
# time cost punc:  0.005932331085205078
# 2024-04-15 08:49:06,570 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:06,580 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.039095163345336914
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.08397531509399414
# 100% 1/1 [00:00<00:00, 11.84it/s]
# total time cost asr:  0.08486676216125488
# time cost punc:  0.005795717239379883
# 2024-04-15 08:49:07,009 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:07,020 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.057932138442993164
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.08977794647216797
# 100% 2/2 [00:00<00:00, 22.13it/s]
# total time cost asr:  0.09076571464538574
# time cost punc:  0.005994081497192383
# 2024-04-15 08:49:07,487 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:07,498 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.04023098945617676
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.09445595741271973
# 100% 1/1 [00:00<00:00, 10.53it/s]
# total time cost asr:  0.0953528881072998
# time cost punc:  0.005643367767333984
# 2024-04-15 08:49:07,946 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:07,957 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.04806995391845703
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.10169720649719238
# 100% 1/1 [00:00<00:00,  9.76it/s]
# total time cost asr:  0.1027688980102539
# time cost punc:  0.006649494171142578
# 2024-04-15 08:49:08,426 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:08,439 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.0524439811706543
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.09334707260131836
# 100% 1/1 [00:00<00:00, 10.63it/s]
# total time cost asr:  0.09446930885314941
# time cost punc:  0.00619053840637207
# 2024-04-15 08:49:08,894 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:08,906 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.05664706230163574
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.09085774421691895
# 100% 2/2 [00:00<00:00, 21.86it/s]
# total time cost asr:  0.09188103675842285
# time cost punc:  0.006342649459838867
# 2024-04-15 08:49:09,382 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:09,395 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.03431844711303711
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.0846867561340332
# 100% 1/1 [00:00<00:00, 11.73it/s]
# total time cost asr:  0.08567571640014648
# time cost punc:  0.006395578384399414
# 2024-04-15 08:49:09,849 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:09,860 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.036150455474853516
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.08743858337402344
# 100% 2/2 [00:00<00:00, 22.71it/s]
# total time cost asr:  0.08849310874938965
# time cost punc:  0.006395101547241211
# 2024-04-15 08:49:10,304 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:10,317 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.046703338623046875
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.08946633338928223
# 100% 2/2 [00:00<00:00, 22.19it/s]
# total time cost asr:  0.09050846099853516
# time cost punc:  0.0060956478118896484
# 2024-04-15 08:49:10,785 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:10,800 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.05584883689880371
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.0878438949584961
# 100% 2/2 [00:00<00:00, 22.61it/s]
# total time cost asr:  0.0888519287109375
# time cost punc:  0.005885124206542969
# 2024-04-15 08:49:11,267 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:11,278 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.04364967346191406
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.09097075462341309
# 100% 1/1 [00:00<00:00, 10.92it/s]
# total time cost asr:  0.09198784828186035
# time cost punc:  0.00589442253112793
# 2024-04-15 08:49:11,744 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:11,756 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.042125701904296875
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.08541417121887207
# 100% 2/2 [00:00<00:00, 23.20it/s]
# total time cost asr:  0.08661484718322754
# time cost punc:  0.005724191665649414
# 2024-04-15 08:49:12,207 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:12,217 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.06728625297546387
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.11603569984436035
# 100% 1/1 [00:00<00:00,  8.55it/s]
# total time cost asr:  0.11735272407531738
# time cost punc:  0.0072116851806640625
# 2024-04-15 08:49:12,910 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:12,929 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.11110758781433105
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.11554193496704102
# 100% 2/2 [00:00<00:00, 17.15it/s]
# total time cost asr:  0.117218017578125
# time cost punc:  0.00777435302734375
# 2024-04-15 08:49:13,688 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:13,708 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.06697654724121094
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.13431072235107422
# 100% 1/1 [00:00<00:00,  7.40it/s]
# total time cost asr:  0.13562703132629395
# time cost punc:  0.007594585418701172
# 2024-04-15 08:49:14,423 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:14,441 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.06447935104370117
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.12522029876708984
# 100% 2/2 [00:00<00:00, 15.87it/s]
# total time cost asr:  0.12642765045166016
# time cost punc:  0.00902247428894043
# 2024-04-15 08:49:15,155 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:15,175 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.04820656776428223
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.09367704391479492
# 100% 2/2 [00:00<00:00, 21.21it/s]
# total time cost asr:  0.09468579292297363
# time cost punc:  0.006033658981323242
# 2024-04-15 08:49:15,682 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:15,693 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.04673624038696289
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.0873258113861084
# 100% 2/2 [00:00<00:00, 22.74it/s]
# total time cost asr:  0.0883493423461914
# time cost punc:  0.0064465999603271484
# 2024-04-15 08:49:16,148 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:16,158 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.03862428665161133
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.08419609069824219
# 100% 1/1 [00:00<00:00, 11.80it/s]
# total time cost asr:  0.08522510528564453
# time cost punc:  0.005647182464599609
# 2024-04-15 08:49:16,585 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:16,596 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.04447007179260254
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.08267474174499512
# 100% 2/2 [00:00<00:00, 23.98it/s]
# total time cost asr:  0.08386945724487305
# time cost punc:  0.00596928596496582
# 2024-04-15 08:49:17,052 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:17,062 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.03593945503234863
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.08576726913452148
# 100% 1/1 [00:00<00:00, 11.59it/s]
# total time cost asr:  0.08665251731872559
# time cost punc:  0.005736589431762695
# 2024-04-15 08:49:17,489 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:17,502 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.045374393463134766
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.0907602310180664
# 100% 1/1 [00:00<00:00, 10.96it/s]
# total time cost asr:  0.09165787696838379
# time cost punc:  0.006093502044677734
# 2024-04-15 08:49:17,967 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:17,978 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.05120563507080078
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.08759665489196777
# 100% 1/1 [00:00<00:00, 11.35it/s]
# total time cost asr:  0.08852863311767578
# time cost punc:  0.005739688873291016
# 2024-04-15 08:49:18,433 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:18,444 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.04628777503967285
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.08479547500610352
# 100% 2/2 [00:00<00:00, 23.42it/s]
# total time cost asr:  0.08575558662414551
# time cost punc:  0.005400896072387695
# 2024-04-15 08:49:18,903 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:18,913 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.05066061019897461
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.09583878517150879
# 100% 2/2 [00:00<00:00, 20.74it/s]
# total time cost asr:  0.09684348106384277
# time cost punc:  0.005767345428466797
# 2024-04-15 08:49:19,376 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:19,387 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.06859111785888672
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.09435200691223145
# 100% 1/1 [00:00<00:00, 10.53it/s]
# total time cost asr:  0.09537720680236816
# time cost punc:  0.007178783416748047
# 2024-04-15 08:49:19,873 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:19,887 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.05376577377319336
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.09153890609741211
# 100% 1/1 [00:00<00:00, 10.85it/s]
# total time cost asr:  0.0925590991973877
# time cost punc:  0.0060579776763916016
# 2024-04-15 08:49:20,350 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:20,361 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.05623984336853027
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.1235806941986084
# 100% 1/1 [00:00<00:00,  8.04it/s]
# total time cost asr:  0.12472701072692871
# time cost punc:  0.0065190792083740234
# 2024-04-15 08:49:20,862 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:20,874 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.050283193588256836
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.0930628776550293
# 100% 1/1 [00:00<00:00, 10.68it/s]
# total time cost asr:  0.09400510787963867
# time cost punc:  0.00613713264465332
# 2024-04-15 08:49:21,339 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:21,350 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.04109501838684082
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.09566330909729004
# 100% 1/1 [00:00<00:00, 10.40it/s]
# total time cost asr:  0.09648847579956055
# time cost punc:  0.005396366119384766
# 2024-04-15 08:49:21,810 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:21,821 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.054422616958618164
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.09073233604431152
# 100% 1/1 [00:00<00:00, 10.95it/s]
# total time cost asr:  0.09170699119567871
# time cost punc:  0.005816936492919922
# 2024-04-15 08:49:22,287 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:22,298 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.02903890609741211
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.1009361743927002
# 100% 1/1 [00:00<00:00,  9.85it/s]
# total time cost asr:  0.1017913818359375
# time cost punc:  0.005892038345336914
# 2024-04-15 08:49:22,747 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:22,759 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.043096303939819336
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.08759880065917969
# 100% 1/1 [00:00<00:00, 11.35it/s]
# total time cost asr:  0.0885324478149414
# time cost punc:  0.005885124206542969
# 2024-04-15 08:49:23,216 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:23,227 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.04904627799987793
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.08629035949707031
# 100% 1/1 [00:00<00:00, 11.51it/s]
# total time cost asr:  0.08727884292602539
# time cost punc:  0.00642704963684082
# 2024-04-15 08:49:23,687 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:23,697 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.054204463958740234
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.08382797241210938
# 100% 2/2 [00:00<00:00, 23.70it/s]
# total time cost asr:  0.08476018905639648
# time cost punc:  0.006029605865478516
# 2024-04-15 08:49:24,151 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:24,162 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.050444602966308594
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.08670377731323242
# 100% 2/2 [00:00<00:00, 22.91it/s]
# total time cost asr:  0.08767104148864746
# time cost punc:  0.005321979522705078
# 2024-04-15 08:49:24,608 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:24,619 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.03740978240966797
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.08178544044494629
# 100% 1/1 [00:00<00:00, 12.15it/s]
# total time cost asr:  0.08272933959960938
# time cost punc:  0.005609035491943359
# 2024-04-15 08:49:25,066 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:25,077 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.06485390663146973
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.13057827949523926
# 100% 1/1 [00:00<00:00,  7.61it/s]
# total time cost asr:  0.1322770118713379
# time cost punc:  0.008795022964477539
# 2024-04-15 08:49:25,653 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:25,669 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.06779003143310547
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.11416339874267578
# 100% 1/1 [00:00<00:00,  8.69it/s]
# total time cost asr:  0.11544990539550781
# time cost punc:  0.006716489791870117
# 2024-04-15 08:49:26,374 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:26,392 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.0742487907409668
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.12586092948913574
# 100% 1/1 [00:00<00:00,  7.89it/s]
# total time cost asr:  0.1271512508392334
# time cost punc:  0.008850336074829102
# 2024-04-15 08:49:27,125 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:27,143 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.09889912605285645
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.14443731307983398
# 100% 1/1 [00:00<00:00,  6.88it/s]
# total time cost asr:  0.14585423469543457
# time cost punc:  0.010004043579101562
# 2024-04-15 08:49:27,922 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:27,943 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.04197287559509277
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.08549022674560547
# 100% 2/2 [00:00<00:00, 23.25it/s]
# total time cost asr:  0.08640170097351074
# time cost punc:  0.005500078201293945
# 2024-04-15 08:49:28,560 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:28,574 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.04912447929382324
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.09351730346679688
# 100% 2/2 [00:00<00:00, 21.24it/s]
# total time cost asr:  0.09458088874816895
# time cost punc:  0.005769968032836914
# 2024-04-15 08:49:29,032 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:29,042 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.04230833053588867
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.08595633506774902
# 100% 1/1 [00:00<00:00, 11.56it/s]
# total time cost asr:  0.08689761161804199
# time cost punc:  0.00581669807434082
# 2024-04-15 08:49:29,498 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:29,510 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.04845142364501953
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.08804869651794434
# 100% 2/2 [00:00<00:00, 22.56it/s]
# total time cost asr:  0.08905529975891113
# time cost punc:  0.005694150924682617
# 2024-04-15 08:49:29,965 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:29,979 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.0785222053527832
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.09365415573120117
# 100% 2/2 [00:00<00:00, 21.19it/s]
# total time cost asr:  0.0947427749633789
# time cost punc:  0.006411552429199219
# 2024-04-15 08:49:30,483 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:30,495 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.043122291564941406
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.09028959274291992
# 100% 1/1 [00:00<00:00, 11.01it/s]
# total time cost asr:  0.09122753143310547
# time cost punc:  0.006034135818481445
# 2024-04-15 08:49:30,947 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:30,959 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.051827430725097656
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.0899209976196289
# 100% 2/2 [00:00<00:00, 22.10it/s]
# total time cost asr:  0.09086847305297852
# time cost punc:  0.005649089813232422
# 2024-04-15 08:49:31,431 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:31,442 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.0571904182434082
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.09557723999023438
# 100% 2/2 [00:00<00:00, 20.76it/s]
# total time cost asr:  0.09673690795898438
# time cost punc:  0.006197690963745117
# 2024-04-15 08:49:31,920 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:31,932 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.048555612564086914
#   0% 0/2 [00:00<?, ?it/s]batch:  2
# time cost asr:  0.09224677085876465
# 100% 2/2 [00:00<00:00, 21.55it/s]
# total time cost asr:  0.0931859016418457
# time cost punc:  0.005734920501708984
# 2024-04-15 08:49:32,393 - modelscope - INFO - Computing the result of ASR ...
# 2024-04-15 08:49:32,406 - modelscope - INFO - Decoding with wav files ...
# batch_size_token:  6000
# time cost vad:  0.04912376403808594
#   0% 0/1 [00:00<?, ?it/s]batch:  1
# time cost asr:  0.09154057502746582
# 100% 1/1 [00:00<00:00, 10.86it/s]
# total time cost asr:  0.09242391586303711
# time cost punc:  0.0058896541595458984
# 2024-04-15 08:49:32,864 - modelscope - INFO - Computing the result of ASR ...
# "/usr/bin/python3" tools/subfix_webui.py --load_list "output/asr_opt/slicer_opt.list" --webui_port 9871
# /usr/local/lib/python3.10/dist-packages/gradio_client/documentation.py:103: UserWarning: Could not get documentation group for <class 'gradio.mix.Parallel'>: No known documentation group for module 'gradio.mix'
#   warnings.warn(f"Could not get documentation group for {cls}: {exc}")
# /usr/local/lib/python3.10/dist-packages/gradio_client/documentation.py:103: UserWarning: Could not get documentation group for <class 'gradio.mix.Series'>: No known documentation group for module 'gradio.mix'
#   warnings.warn(f"Could not get documentation group for {cls}: {exc}")
# /content/gpt-sovits/tools/subfix_webui.py:361: GradioUnusedKwargWarning: You have unused kwarg parameters in Button, please remove them: {'link': '?__theme=light'}
#   btn_theme_dark = gr.Button("Light Theme", link="?__theme=light", scale=1)
# /content/gpt-sovits/tools/subfix_webui.py:362: GradioUnusedKwargWarning: You have unused kwarg parameters in Button, please remove them: {'link': '?__theme=dark'}
#   btn_theme_light = gr.Button("Dark Theme", link="?__theme=dark", scale=1)
# Running on local URL:  http://0.0.0.0:9871
# Running on public URL: https://b473b725e325476b98.gradio.live
# "/usr/bin/python3" GPT_SoVITS/prepare_datasets/1-get-text.py
# "/usr/bin/python3" GPT_SoVITS/prepare_datasets/1-get-text.py
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /content/gpt-sovits/TEMP/jieba.cache
# Dumping model to file cache /content/gpt-sovits/TEMP/jieba.cache
# Loading model cost 1.237 seconds.
# Prefix dict has been built successfully.
# Loading model cost 1.280 seconds.
# Prefix dict has been built successfully.
# "/usr/bin/python3" GPT_SoVITS/prepare_datasets/2-get-hubert-wav32k.py
# "/usr/bin/python3" GPT_SoVITS/prepare_datasets/2-get-hubert-wav32k.py
# Some weights of the model checkpoint at GPT_SoVITS/pretrained_models/chinese-hubert-base were not used when initializing HubertModel: ['encoder.pos_conv_embed.conv.weight_g', 'encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing HubertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing HubertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at GPT_SoVITS/pretrained_models/chinese-hubert-base were not used when initializing HubertModel: ['encoder.pos_conv_embed.conv.weight_g', 'encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing HubertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing HubertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of HubertModel were not initialized from the model checkpoint at GPT_SoVITS/pretrained_models/chinese-hubert-base and are newly initialized: ['encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of HubertModel were not initialized from the model checkpoint at GPT_SoVITS/pretrained_models/chinese-hubert-base and are newly initialized: ['encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# "/usr/bin/python3" GPT_SoVITS/prepare_datasets/3-get-semantic.py
# "/usr/bin/python3" GPT_SoVITS/prepare_datasets/3-get-semantic.py
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# <All keys matched successfully>
# <All keys matched successfully>
# "/usr/bin/python3" GPT_SoVITS/s2_train.py --config "TEMP/tmp_s2.json"
# 2024-04-15 08:55:04.526886: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-15 08:55:04.526944: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-15 08:55:04.639195: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-15 08:55:04.860693: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-15 08:55:07.078119: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-15 08:55:12.284865: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-15 08:55:12.284918: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-15 08:55:12.286204: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-15 08:55:13.416280: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# phoneme_data_len: 65
# wav_data_len: 85
# 100% 85/85 [00:00<00:00, 98894.82it/s]
# skipped_phone:  0 , skipped_dur:  0
# total left:  85
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# ssl_proj.weight not requires_grad
# ssl_proj.bias not requires_grad
# <All keys matched successfully>
# <All keys matched successfully>
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 0it [00:00, ?it/s]2024-04-15 08:55:33.093909: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-15 08:55:33.093997: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-15 08:55:33.101223: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-15 08:55:33.824424: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-15 08:55:33.828798: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-15 08:55:33.830600: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-15 08:55:34.307141: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-15 08:55:34.307196: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-15 08:55:34.322891: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-15 08:55:34.411734: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-15 08:55:34.422824: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-15 08:55:34.424581: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-15 08:55:34.439081: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-15 08:55:34.447772: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-15 08:55:34.449510: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-15 08:55:34.823664: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-15 08:55:34.826769: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-15 08:55:34.828480: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-15 08:55:40.295561: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-15 08:55:41.237004: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-15 08:55:41.374939: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-15 08:55:41.378221: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-15 08:55:41.568621: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-15 08:55:41.685898: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:660: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at ../aten/src/ATen/native/SpectralOps.cpp:874.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:660: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at ../aten/src/ATen/native/SpectralOps.cpp:874.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:660: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at ../aten/src/ATen/native/SpectralOps.cpp:874.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:660: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at ../aten/src/ATen/native/SpectralOps.cpp:874.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:660: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at ../aten/src/ATen/native/SpectralOps.cpp:874.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:660: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at ../aten/src/ATen/native/SpectralOps.cpp:874.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# [rank0]:[W reducer.cpp:1360] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:660: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at ../aten/src/ATen/native/SpectralOps.cpp:874.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:660: UserWarning: ComplexHalf support is experimental and many operators don't support it yet. (Triggered internally at ../aten/src/ATen/EmptyTensor.cpp:30.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py:266: UserWarning: Grad strides do not match bucket view strides. This may indicate grad was not created according to the gradient layout contract, or that the param's strides changed since DDP was constructed.  This is not an error, but may impair performance.
# grad.sizes() = [1, 9, 96], strides() = [53280, 96, 1]
# bucket_view.sizes() = [1, 9, 96], strides() = [864, 96, 1] (Triggered internally at ../torch/csrc/distributed/c10d/reducer.cpp:322.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# 13it [00:57,  4.40s/it]
# 13it [00:17,  1.36s/it]
# 13it [00:16,  1.30s/it]
# 13it [00:17,  1.33s/it]
# 13it [00:17,  1.33s/it]
# 13it [00:17,  1.37s/it]
# 13it [00:16,  1.24s/it]
# 13it [00:17,  1.38s/it]
# "/usr/bin/python3" GPT_SoVITS/s1_train.py --config_file "TEMP/tmp_s1.yaml"
# Seed set to 1234
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# <All keys matched successfully>
# ckpt_path: None
# [rank: 0] Seed set to 1234
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# Missing logger folder: logs/ai/logs_s1/logs_s1
# 2024-04-15 08:59:09.171826: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-15 08:59:09.171883: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-15 08:59:09.173336: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-15 08:59:10.660588: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# semantic_data_len: 17
# phoneme_data_len: 65
#                         item_name                                     semantic_audio
# 0   ai合成音.MP3_5490560_5639360.wav  520 271 271 271 53 271 271 72 540 1002 606 346...
# 1   ai合成音.MP3_5992320_6169280.wav  520 271 271 105 105 105 105 280 105 53 234 360...
# 2   ai合成音.MP3_1625280_1847680.wav  520 271 105 105 105 105 105 280 105 105 234 36...
# 3   ai合成音.MP3_3771520_3896000.wav  520 105 105 721 991 5 809 505 140 8 397 468 84...
# 4     ai合成音.MP3_736000_870720.wav  520 8 5 721 17 463 945 169 597 510 112 137 300...
# 5   ai合成音.MP3_1972480_2085120.wav  520 271 105 105 105 105 105 280 105 105 53 72 ...
# 6   ai合成音.MP3_5194560_5357760.wav  520 271 105 105 105 105 105 105 105 105 271 72...
# 7   ai合成音.MP3_6318720_6492480.wav  520 271 105 105 520 53 72 965 902 943 178 621 ...
# 8   ai合成音.MP3_4474560_4622080.wav  54 17 177 597 839 64 840 5 778 893 962 11 220 ...
# 9   ai合成音.MP3_3896000_4017920.wav  520 105 105 105 1012 875 105 105 105 271 490 9...
# 10   ai合成音.MP3_878080_1020480.wav  520 271 53 774 365 170 1005 274 956 922 410 42...
# 11  ai合成音.MP3_5357760_5490560.wav  520 271 271 53 271 72 774 773 124 425 667 591 ...
# 12  ai合成音.MP3_6169280_6318720.wav  520 271 271 271 41 171 467 467 425 607 346 156...
# 13  ai合成音.MP3_5834240_5989120.wav  520 271 105 105 105 105 280 280 280 105 53 98 ...
# 14    ai合成音.MP3_404800_532480.wav  520 271 105 105 105 105 105 280 105 105 53 405...
# 15  ai合成音.MP3_6784320_7004800.wav  520 72 505 492 200 202 346 397 485 683 745 705...
# 16  ai合成音.MP3_6492480_6656000.wav  520 271 105 105 105 105 280 105 105 271 72 214...
# dataset.__len__(): 85
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type                 | Params
# -----------------------------------------------
# 0 | model | Text2SemanticDecoder | 77.5 M
# -----------------------------------------------
# 77.5 M    Trainable params
# 0         Non-trainable params
# 77.5 M    Total params
# 309.975   Total estimated model params size (MB)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loops/fit_loop.py:298: The number of training batches (13) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 14: 100% 13/13 [00:01<00:00,  7.48it/s, v_num=0, total_loss_step=28.00, lr_step=0.002, top_3_acc_step=1.000, total_loss_epoch=254.0, lr_epoch=0.002, top_3_acc_epoch=0.999]`Trainer.fit` stopped: `max_epochs=15` reached.
# Epoch 14: 100% 13/13 [00:16<00:00,  1.26s/it, v_num=0, total_loss_step=28.00, lr_step=0.002, top_3_acc_step=1.000, total_loss_epoch=254.0, lr_epoch=0.002, top_3_acc_epoch=0.999]
# "/usr/bin/python3" GPT_SoVITS/inference_webui.py
# /usr/local/lib/python3.10/dist-packages/gradio_client/documentation.py:103: UserWarning: Could not get documentation group for <class 'gradio.mix.Parallel'>: No known documentation group for module 'gradio.mix'
#   warnings.warn(f"Could not get documentation group for {cls}: {exc}")
# /usr/local/lib/python3.10/dist-packages/gradio_client/documentation.py:103: UserWarning: Could not get documentation group for <class 'gradio.mix.Series'>: No known documentation group for module 'gradio.mix'
#   warnings.warn(f"Could not get documentation group for {cls}: {exc}")
# Some weights of the model checkpoint at GPT_SoVITS/pretrained_models/chinese-hubert-base were not used when initializing HubertModel: ['encoder.pos_conv_embed.conv.weight_g', 'encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing HubertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing HubertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of HubertModel were not initialized from the model checkpoint at GPT_SoVITS/pretrained_models/chinese-hubert-base and are newly initialized: ['encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# _IncompatibleKeys(missing_keys=['enc_q.pre.weight', 'enc_q.pre.bias', 'enc_q.enc.in_layers.0.bias', 'enc_q.enc.in_layers.0.weight_g', 'enc_q.enc.in_layers.0.weight_v', 'enc_q.enc.in_layers.1.bias', 'enc_q.enc.in_layers.1.weight_g', 'enc_q.enc.in_layers.1.weight_v', 'enc_q.enc.in_layers.2.bias', 'enc_q.enc.in_layers.2.weight_g', 'enc_q.enc.in_layers.2.weight_v', 'enc_q.enc.in_layers.3.bias', 'enc_q.enc.in_layers.3.weight_g', 'enc_q.enc.in_layers.3.weight_v', 'enc_q.enc.in_layers.4.bias', 'enc_q.enc.in_layers.4.weight_g', 'enc_q.enc.in_layers.4.weight_v', 'enc_q.enc.in_layers.5.bias', 'enc_q.enc.in_layers.5.weight_g', 'enc_q.enc.in_layers.5.weight_v', 'enc_q.enc.in_layers.6.bias', 'enc_q.enc.in_layers.6.weight_g', 'enc_q.enc.in_layers.6.weight_v', 'enc_q.enc.in_layers.7.bias', 'enc_q.enc.in_layers.7.weight_g', 'enc_q.enc.in_layers.7.weight_v', 'enc_q.enc.in_layers.8.bias', 'enc_q.enc.in_layers.8.weight_g', 'enc_q.enc.in_layers.8.weight_v', 'enc_q.enc.in_layers.9.bias', 'enc_q.enc.in_layers.9.weight_g', 'enc_q.enc.in_layers.9.weight_v', 'enc_q.enc.in_layers.10.bias', 'enc_q.enc.in_layers.10.weight_g', 'enc_q.enc.in_layers.10.weight_v', 'enc_q.enc.in_layers.11.bias', 'enc_q.enc.in_layers.11.weight_g', 'enc_q.enc.in_layers.11.weight_v', 'enc_q.enc.in_layers.12.bias', 'enc_q.enc.in_layers.12.weight_g', 'enc_q.enc.in_layers.12.weight_v', 'enc_q.enc.in_layers.13.bias', 'enc_q.enc.in_layers.13.weight_g', 'enc_q.enc.in_layers.13.weight_v', 'enc_q.enc.in_layers.14.bias', 'enc_q.enc.in_layers.14.weight_g', 'enc_q.enc.in_layers.14.weight_v', 'enc_q.enc.in_layers.15.bias', 'enc_q.enc.in_layers.15.weight_g', 'enc_q.enc.in_layers.15.weight_v', 'enc_q.enc.res_skip_layers.0.bias', 'enc_q.enc.res_skip_layers.0.weight_g', 'enc_q.enc.res_skip_layers.0.weight_v', 'enc_q.enc.res_skip_layers.1.bias', 'enc_q.enc.res_skip_layers.1.weight_g', 'enc_q.enc.res_skip_layers.1.weight_v', 'enc_q.enc.res_skip_layers.2.bias', 'enc_q.enc.res_skip_layers.2.weight_g', 'enc_q.enc.res_skip_layers.2.weight_v', 'enc_q.enc.res_skip_layers.3.bias', 'enc_q.enc.res_skip_layers.3.weight_g', 'enc_q.enc.res_skip_layers.3.weight_v', 'enc_q.enc.res_skip_layers.4.bias', 'enc_q.enc.res_skip_layers.4.weight_g', 'enc_q.enc.res_skip_layers.4.weight_v', 'enc_q.enc.res_skip_layers.5.bias', 'enc_q.enc.res_skip_layers.5.weight_g', 'enc_q.enc.res_skip_layers.5.weight_v', 'enc_q.enc.res_skip_layers.6.bias', 'enc_q.enc.res_skip_layers.6.weight_g', 'enc_q.enc.res_skip_layers.6.weight_v', 'enc_q.enc.res_skip_layers.7.bias', 'enc_q.enc.res_skip_layers.7.weight_g', 'enc_q.enc.res_skip_layers.7.weight_v', 'enc_q.enc.res_skip_layers.8.bias', 'enc_q.enc.res_skip_layers.8.weight_g', 'enc_q.enc.res_skip_layers.8.weight_v', 'enc_q.enc.res_skip_layers.9.bias', 'enc_q.enc.res_skip_layers.9.weight_g', 'enc_q.enc.res_skip_layers.9.weight_v', 'enc_q.enc.res_skip_layers.10.bias', 'enc_q.enc.res_skip_layers.10.weight_g', 'enc_q.enc.res_skip_layers.10.weight_v', 'enc_q.enc.res_skip_layers.11.bias', 'enc_q.enc.res_skip_layers.11.weight_g', 'enc_q.enc.res_skip_layers.11.weight_v', 'enc_q.enc.res_skip_layers.12.bias', 'enc_q.enc.res_skip_layers.12.weight_g', 'enc_q.enc.res_skip_layers.12.weight_v', 'enc_q.enc.res_skip_layers.13.bias', 'enc_q.enc.res_skip_layers.13.weight_g', 'enc_q.enc.res_skip_layers.13.weight_v', 'enc_q.enc.res_skip_layers.14.bias', 'enc_q.enc.res_skip_layers.14.weight_g', 'enc_q.enc.res_skip_layers.14.weight_v', 'enc_q.enc.res_skip_layers.15.bias', 'enc_q.enc.res_skip_layers.15.weight_g', 'enc_q.enc.res_skip_layers.15.weight_v', 'enc_q.enc.cond_layer.bias', 'enc_q.enc.cond_layer.weight_g', 'enc_q.enc.cond_layer.weight_v', 'enc_q.proj.weight', 'enc_q.proj.bias'], unexpected_keys=[])
# Number of parameter: 77.49M
# Running on local URL:  http://0.0.0.0:9872
# Running on public URL: https://d4e7889a3ed49cfd72.gradio.live
# Building prefix dict from the default dictionary ...
# DEBUG:jieba:Building prefix dict from the default dictionary ...
# Loading model from cache /content/gpt-sovits/TEMP/jieba.cache
# DEBUG:jieba:Loading model from cache /content/gpt-sovits/TEMP/jieba.cache
# Loading model cost 1.210 seconds.
# DEBUG:jieba:Loading model cost 1.210 seconds.
# Prefix dict has been built successfully.
# DEBUG:jieba:Prefix dict has been built successfully.
#   8% 124/1500 [00:02<00:22, 59.88it/s]T2S Decoding EOS [311 -> 440]
#   9% 129/1500 [00:02<00:30, 44.37it/s]
# min value is  tensor(-1.3007)
# max value is  tensor(1.3124)
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:660: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at ../aten/src/ATen/native/SpectralOps.cpp:874.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# 2.712	1.325	2.915	0.858
#   5% 69/1500 [00:01<00:22, 62.90it/s]T2S Decoding EOS [311 -> 381]
#   5% 70/1500 [00:01<00:23, 61.23it/s]
# min value is  tensor(-1.3007)
# max value is  tensor(1.3124)
#   4% 63/1500 [00:00<00:22, 63.91it/s]T2S Decoding EOS [311 -> 376]
#   4% 65/1500 [00:01<00:22, 62.57it/s]
# min value is  tensor(-1.3007)
# max value is  tensor(1.3124)
# 0.481	1.836	1.040	0.791
#   7% 98/1500 [00:01<00:22, 62.23it/s]T2S Decoding EOS [311 -> 412]
#   7% 101/1500 [00:01<00:22, 61.80it/s]
# min value is  tensor(-1.3007)
# max value is  tensor(1.3124)
# 0.473	0.052	1.635	0.468
#   7% 98/1500 [00:01<00:22, 63.11it/s]T2S Decoding EOS [311 -> 411]
#   7% 100/1500 [00:01<00:22, 62.00it/s]
# min value is  tensor(-1.3007)
# max value is  tensor(1.3124)
# 0.470	0.048	1.614	0.452
#  21% 308/1500 [00:05<00:19, 61.25it/s]T2S Decoding EOS [311 -> 620]
#  21% 309/1500 [00:06<00:23, 51.33it/s]
# min value is  tensor(-1.3007)
# max value is  tensor(1.3124)
# 0.478	0.056	6.022	0.517
#   5% 80/1500 [00:01<00:34, 40.88it/s]T2S Decoding EOS [311 -> 394]
#   6% 83/1500 [00:02<00:35, 40.19it/s]
# min value is  tensor(-1.3007)
# max value is  tensor(1.3124)
#   6% 91/1500 [00:01<00:23, 60.02it/s]T2S Decoding EOS [311 -> 407]
#   6% 96/1500 [00:01<00:23, 60.58it/s]
# min value is  tensor(-1.3007)
# max value is  tensor(1.3124)
#   6% 88/1500 [00:01<00:23, 59.36it/s]T2S Decoding EOS [311 -> 404]
#   6% 93/1500 [00:01<00:24, 57.66it/s]
# min value is  tensor(-1.3007)
# max value is  tensor(1.3124)
# 0.882	4.800	1.614	0.507
#   9% 132/1500 [00:02<00:21, 62.19it/s]T2S Decoding EOS [311 -> 446]
#   9% 135/1500 [00:02<00:22, 61.14it/s]
# min value is  tensor(-1.3007)
# max value is  tensor(1.3124)
#   4% 55/1500 [00:00<00:23, 60.79it/s]T2S Decoding EOS [311 -> 371]
#   4% 60/1500 [00:01<00:24, 59.29it/s]
# min value is  tensor(-1.3007)
# max value is  tensor(1.3124)
#   4% 66/1500 [00:01<00:34, 41.10it/s]T2S Decoding EOS [311 -> 377]
#   4% 66/1500 [00:01<00:33, 43.32it/s]
# min value is  tensor(-1.3007)
# max value is  tensor(1.3124)
# 0.472	4.648	1.525	0.749
#   6% 84/1500 [00:01<00:22, 62.78it/s]T2S Decoding EOS [311 -> 399]
#   6% 88/1500 [00:01<00:22, 61.93it/s]
# min value is  tensor(-1.3007)
# max value is  tensor(1.3124)
#   6% 91/1500 [00:01<00:22, 61.28it/s]T2S Decoding EOS [311 -> 405]
#   6% 94/1500 [00:01<00:22, 61.40it/s]
# min value is  tensor(-1.3007)
# max value is  tensor(1.3124)
#   6% 92/1500 [00:02<00:35, 39.34it/s]T2S Decoding EOS [311 -> 406]
#   6% 95/1500 [00:02<00:34, 40.83it/s]
# min value is  tensor(-1.3007)
# max value is  tensor(1.3124)
# 0.479	4.303	2.328	0.568

# %%
from google.colab import drive
drive.mount('/content/drive')
